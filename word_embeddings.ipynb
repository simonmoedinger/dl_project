# %%
import os
os.environ['TRANSFORMERS_CACHE'] = '/home/smoeding/caches/'
os.environ['XDG_CACHE_HOME'] = '/home/smoeding/caches/'
import math

import numpy as np
from transformers import AutoModelForCausalLM, AutoTokenizer, TextStreamer, GenerationConfig
import torch
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import math
from sklearn.metrics import accuracy_score
import plotly.express as px
from plotly import graph_objects as go
# Out:
# /home/smoeding/.local/lib/python3.9/site-packages/transformers/utils/hub.py:123: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
icd_codes = pd.read_csv("icd10gm2024syst_kodes.txt", sep=";", header=None)

# %%
icd_codes.head()
# Out:
#    0  1  2   3    4      5      6     7   \
# 0   3  N  X   1  A00  A00.-    A00   A00
# 1   4  T  X   1  A00  A00.0  A00.0  A000
# 2   4  T  X   1  A00  A00.1  A00.1  A001
# 3   4  T  X   1  A00  A00.9  A00.9  A009
# 4   3  N  X   1  A00  A01.-    A01   A01
#
#                                                   8   \
# 0                                            Cholera
# 1  Cholera durch Vibrio cholerae O:1, Biovar chol...
# 2    Cholera durch Vibrio cholerae O:1, Biovar eltor
# 3                    Cholera, nicht näher bezeichnet
# 4                  Typhus abdominalis und Paratyphus
#
#                                   9   ...   18 19 20    21    22 23 24 25 26  \
# 0                            Cholera  ...  001  9  9  9999  9999  9  J  J  J
# 1                            Cholera  ...  001  9  9  9999  9999  9  J  J  J
# 2                            Cholera  ...  001  9  9  9999  9999  9  J  J  J
# 3                            Cholera  ...  001  9  9  9999  9999  9  J  J  J
# 4  Typhus abdominalis und Paratyphus  ...  002  9  9  9999  9999  9  N  J  J
#
#   27
# 0  J
# 1  J
# 2  J
# 3  J
# 4  J
#
# [5 rows x 28 columns]

# %%
diseases = list(set(icd_codes[9]))

# %%
diseases = [item for item in diseases if "Sonstige" not in item]
diseases = [item for item in diseases if "Nicht belegte Schlüssel" not in item]
diseases = [item for item in diseases if "Nicht näher bezeichnet" not in item]

# %%
len(diseases)
# Out:
# 1377

# %%
model_name = "LeoLM/leo-mistral-hessianai-7b"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.bfloat16,
)
# Out:
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
tokenizer=AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token_id=tokenizer.eos_token_id

# %%
def get_embeddings(model, tokenizer, text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True).to(model.device)
    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True)
    embeddings = outputs.hidden_states[-1].mean(dim=1) # Mean pooling over tokens
    
    return embeddings

# %%
test_diseases = ["Alzheimer", "Tremor", "Unwillkürliche Bewegung"]

# %%
embeddings = []
diseases += test_diseases
for disease in diseases:
    embeddings.append(get_embeddings(model, tokenizer, disease).cpu())
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
tsne = TSNE(n_components=2, random_state=1)
X_tsne = tsne.fit_transform(np.array([tensor.float().numpy().reshape(4096) for tensor in embeddings]))
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
df = pd.DataFrame({'x': X_tsne[:,0], 'y': X_tsne[:,1], 'label': diseases})
df['color'] = 'lightblue'

# Additional DataFrame for specific diseases with red color
additional_df = pd.DataFrame()
for disease in test_diseases:
    additional_df = pd.concat([additional_df, pd.DataFrame({
        'x': X_tsne[diseases.index(disease), 0],
        'y': X_tsne[diseases.index(disease), 1],
        'label': disease,
        "color": "red"
    }, index=[1])])


fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df['x'],
    y=df['y'],
    mode='markers',
    marker=dict(color=df['color']),
    text=df['label'],
))
fig.add_trace(go.Scatter(
    x=additional_df['x'],
    y=additional_df['y'],
    mode='markers+text',
    marker=dict(color=additional_df['color']),
    text=additional_df['label'],
))

fig.update_layout(title_text='ICD10 diseases german word embeddings', hovermode='closest', showlegend=False, width=800, height=800)
fig.update_traces(textposition='top center')
fig.show()
# Out:
# <div>                            <div id="55aa7f34-6421-44a1-9942-f0c28b7bf7f6" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55aa7f34-6421-44a1-9942-f0c28b7bf7f6")) {                    Plotly.newPlot(                        "55aa7f34-6421-44a1-9942-f0c28b7bf7f6",                        [{"marker":{"color":["lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lightblue","lig ...
